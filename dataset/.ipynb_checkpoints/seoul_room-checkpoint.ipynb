# %%
import pandas as pd

df = pd.read_csv("seoul_room.csv", encoding="cp949")
df
# Out:
#          매물번호 계약형태      가격정보        건물유형      면적             행정구역  \
# 0    11789103   매매      3500        공동주택   66.10     경기도 부천시 소사본동
# 1    11789097   전세        4억        공동주택   46.12  서울특별시 서대문구 북아현동
# 2    11789093   전세    1억8500        공동주택   47.14    서울특별시 강서구 화곡동
# 3    11789090   월세   1000/50        공동주택       (   서울특별시 동대문구 장안동
# 4    11789085   월세  2000/135        단독주택   66.10    서울특별시 강남구 삼성동
# ..        ...  ...       ...         ...     ...              ...
# 582  11784197   전세    2억4500        공동주택   52.88    서울특별시 은평구 응암동
# 583  11784192   월세    500/45  제1종 근린생활시설   19.83  서울특별시 성동구 성수동1가
# 584  11784176   매매     2억500        공동주택   82.63    서울특별시 관악구 신림동
# 585  11784172   월세   3000/42        단독주택   23.14   서울특별시 마포구 노고산동
# 586  11784170   매매    6억5000        공동주택  114.23    서울특별시 강서구 화곡동
#
#                                        보안시설         위도          경도
# 0                현관보안, CCTV, 인터폰, 비디오폰, 방범창  37.471815  126.796472
# ...
